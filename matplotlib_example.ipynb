# %% [markdown]
# ## Interactive Matplotlib Example

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
z = np.linspace(0, 10)
line, = plt.plot(z, np.sin(z), '--', linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="640">
